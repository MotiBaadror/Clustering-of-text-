# %% [markdown]
# # import of libraries

# %%
import numpy as np
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

# %% [markdown]
# ##code for creating a sentence of 5 words from given sample

# %%
# a='remittance scheme dre cda remit however hsi mto baird bcd bdo credit_suisse day sub post direct provided improved proceeds nri wax per pis performance bsc dated rough efs paisa required sending indirect mash days refinance period nre case beyond concerned sola dae date_of_shipment facility sent excl also ministry_of_finance hsiang lpc transfer polished overseas availed order basis finance prescribed spo ilc receiving wayne jens availing breakout input fine reyes bill supply acu year xian clean fanny received system taking bank substitute goetz incase original semi limit allowed levelof favour precious form reasons exporters use note based show stone excluding provide eligible'
# f=open('0.txt','r')
# string =f.read()

def sentence(a):
#     a='insurer insurance claim loss risk reinsurance life premium policyholder business year underwriting company policy liability capital written based line group actuary product also rate result exposure actuarial reserve annuity casualty catastrophe reinsurers naic property amount expected market development ratio used benefit change estimate paid experience surplus expense non include contract future assumption investment accident due excess pricing reinsurer earned event increase standard state one solvency including level model reported incurred generally value cover industry payment well factor captive ceded cost limit insurance_company method required insured general use gross statutory severity force individual period large provide regulator surrender charge analysis reserving'
    b=a.split(' ')
    c=[]
    d=[]
    for a in range(len(b)):
        i=0
        if a%5==0:
            c.append(d)
            d=[]
        d.append(b[a])
    return c

# %% [markdown]
# # Model Which Is Showing The Words relation as a plot

# %%
sentences=sentence(a)
# train model
model = Word2Vec(sentences, min_count=1)
# fit a 2d PCA model to the vectors
X = model[model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# create a scatter plot of the projection
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words):
	plt.annotate(word, xy=(result[i, 0], result[i, 1]))
# pyplot.show()
plt.figure(figsize=(60,40))
pyplot.show()

print(model)
# Out:
# /home/baadror/anaconda2/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.
# Word2Vec(vocab=95, size=100, alpha=0.025)

# %% [markdown]
# # Unique Words for the given sample so learn the word embedding

# %%
from gensim.models import Word2Vec

sentences=c
model = Word2Vec(sentences, min_count=1)
# print(model)
words = list(model.wv.vocab)
print(words)
# print(model['day'])
# Out:
# ['provide', 'include', 'reported', 'casualty', 'contract', 'reinsurer', 'business', 'insurance_company', 'market', 'assumption', 'severity', 'state', 'estimate', 'used', 'method', 'excess', 'factor', 'accident', 'exposure', 'reinsurers', 'capital', 'experience', 'force', 'insurance', 'incurred', 'including', 'increase', 'policyholder', 'expected', 'non', 'ratio', 'captive', 'paid', 'reserve', 'benefit', 'also', 'expense', 'written', 'product', 'cost', 'company', 'ceded', 'solvency', 'limit', 'development', 'loss', 'level', 'event', 'reinsurance', 'well', 'amount', 'individual', 'due', 'risk', 'group', 'large', 'generally', 'actuarial', 'year', 'model', 'based', 'line', 'premium', 'policy', 'earned', 'required', 'claim', 'one', 'life', 'value', 'underwriting', 'property', 'catastrophe', 'gross', 'general', 'cover', 'payment', 'surplus', 'liability', 'period', 'statutory', 'insured', 'change', 'actuary', 'pricing', 'insurer', 'future', 'industry', 'standard', 'use', 'rate', 'annuity', 
# ...

# %% [markdown]
# # Showing Word Vector For Word Reported

# %%
print(new_model['reported'])
# Out:
# [-4.1075186e-03 -3.2051862e-03  4.1257660e-03 -3.4100856e-03
#   4.8781969e-03 -1.3780667e-03 -3.2893233e-03  2.9970552e-03
#  -8.8055670e-04 -3.9022530e-03 -3.0030552e-03  8.2664477e-04
#   6.6841842e-04  1.7391288e-04 -2.0825111e-03 -1.9172036e-04
#  -1.1090912e-03 -1.9214351e-03 -4.5424206e-03 -3.3087893e-03
#  -3.0957162e-03 -2.2860961e-03  3.4190825e-04  4.4846092e-03
#  -2.6189312e-03 -4.0122098e-03 -3.3273818e-03  4.1205320e-03
#   9.1094145e-04 -1.3687627e-03 -1.7928813e-03  2.4386279e-03
#   3.9007163e-03 -2.5925264e-04  1.5316664e-03 -1.1134871e-03
#   1.0034556e-03  2.9967527e-03  3.1885386e-03  3.6701828e-03
#  -4.4467379e-03 -2.7248906e-03 -2.9412627e-03  3.7786653e-03
#  -3.3360387e-03 -1.0136963e-03 -5.8401725e-04 -2.9370161e-03
#   3.0603209e-03 -4.0295925e-03  1.2295099e-03  3.5460803e-03
#   3.0879703e-05  1.2345525e-03 -1.7482884e-03  3.7957481e-03
#   4.8997381e-04 -2.6188283e-03  7.0153142e-04 -6.5390405e-04
# ...

# %%
X=[]
for i in words:
    X.append(new_model[i])
# Out:
# /home/baadror/anaconda2/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # collecting score for the words which has dot product high => high corelation

# %%
X=np.array(X)

score =[]
for i in X:
    temp=[np.dot(i,j) for j in X]
    pos=np.argmax(temp, axis=0)
    temp[pos]=0
    score.append(temp)
    temp=[]
match1=[]
length=len(X)//3
for i in score:
    temp1=[]
    for j in range(length):
        a=np.argmax(i , axis=0)
        temp1.append(a)
        i[a]=0
    match1.append(temp1)



# matching word of first word     
k=list(match1[0])

for i in k:
    print(words[i])
# Out:
# property
# required
# actuary
# pricing
# also
# product
# future
# premium
# policy
# loss
# cover
# force
# actuarial
# reserve
# based
# estimate
# event
# assumption
# captive
# method
# generally
# policyholder
# expected
# factor
# ceded
# use
# earned
# one
# casualty
# reported
# including

# %%
f=open('input/0.txt','r')
string =f.read()
string
# Out:
# 'remittance scheme dre cda remit however hsi mto baird bcd bdo credit_suisse day sub post direct provided improved proceeds nri wax per pis performance bsc dated rough efs paisa required sending indirect mash days refinance period nre case beyond concerned sola dae date_of_shipment facility sent excl also ministry_of_finance hsiang lpc transfer polished overseas availed order basis finance prescribed spo ilc receiving wayne jens availing breakout input fine reyes bill supply acu year xian clean fanny received system taking bank substitute goetz incase original semi limit allowed levelof favour precious form reasons exporters use note based show stone excluding provide eligible'
